# %%
import pandas as pd

df = pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
#NUMBER OF ROWS & COLUMNS
df.shape
# Out:
# (14620, 23)

# %%
#DATA TYPE & MISSING VALUES
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
#SUMMARY STATISTICS
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
#CHCEK MISSING VALUES
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
#SIMPLE WAY TO REMOVE FOR NOW
df = df.dropna()

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**
#
#
# *   Price distribution
#
# *   Price vs Area
# *   City-wise price comparison
#
#
# *   Correlation heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#PRICE DISTRIBUTION
plt.figure(figsize =(8, 5))
plt.hist(df['Price'], bins = 50)
plt.title('House Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
#LIVING AREA VS PRICE
plt.figure(figsize =(6, 4))
sns.scatterplot(x=df['living area'], y=df['Price'])
plt.title('Living Area VS Price')
plt.xlabel('Living Area')
plt.ylabel('Price')
plt.show()

# %%
#BEDROOM VS PRICE
plt.figure(figsize =(6,4))
sns.scatterplot(x=df['number of bedrooms'], y=df['Price'])
plt.title('Bedroom VS Price')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.show()

# %%
#BATHROOM VS PRICE
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['number of bathrooms'], y=df['Price'])
plt.title('Bathroom VS Price')
plt.xlabel('Bathrooms')
plt.ylabel('Price')
plt.show()

# %%
#CORRELATION MATRIX (WITHOUT SEABORN)
print("\n Correlation matrix:")
corr = df.corr()
print(corr)
# Out:
#  Correlation matrix:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
plt.figure(figsize=(10, 6))
plt.imshow(corr, cmap =None) #NO COLORMAP STYLING
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns, rotation =0)
plt.colorbar()
plt.show()

# %%
#TOP 10 MOST EXPENSIVE HOUSES
top10 = df.sort_values(by='Price', ascending=False).head(10)
print("\n Top 10 Most Expensive Houses:")
print(top10)
# Out:
#  Top 10 Most Expensive Houses:
#                id   Date  number of bedrooms  number of bathrooms  \
# 10503  6762810020  42655                   6                 8.00
# 2424   6762810021  42531                   5                 4.50
# 9171   6762810022  42631                   6                 7.75
# 6244   6762810023  42585                   5                 5.75
# 10915  6762810026  42662                   5                 5.25
# 2794   6762810027  42537                   5                 6.75
# 2907   6762810029  42538                   4                 3.00
# 10566  6762810031  42656                   4                 5.50
# 12442  6762810032  42687                   4                 4.25
# 3946   6762810033  42551                   5                 5.50
#
#        living area  lot area  number of floors  waterfront present  \
# 10503        12050     27600               2.5                   0
# 2424         10040     37325               2.0                   1
# ...

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['grade of the house'], y=df['Price'])
plt.title('Grade of House VS Price')
plt.xlabel('Grade of House')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize =(8,5))
sns.scatterplot(x=df['Built Year'], y=df['Price'])
plt.title('Built Year VS Price')
plt.xlabel('Built Year')
plt.ylabel('Price')
plt.show()

# %%
df.boxplot(column = 'Price', by ="number of bedrooms" , figsize=(8,5))
plt.title('Price Distribution Across Bedrooms')
plt.suptitle("")
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price')
plt.show()

# %%
top10 = df.sort_values(by='Price', ascending=False).head(10)
print(top10[['Price','number of bedrooms','number of bathrooms','Built Year','living area']])
# Out:
#          Price  number of bedrooms  number of bathrooms  Built Year  \
# 10503  7700000                   6                 8.00        1910
# 2424   7060000                   5                 4.50        1940
# 9171   6890000                   6                 7.75        2001
# 6244   5570000                   5                 5.75        2001
# 10915  5110000                   5                 5.25        1999
# 2794   4670000                   5                 6.75        1983
# 2907   4490000                   4                 3.00        2001
# 10566  4000000                   4                 5.50        2008
# 12442  3850000                   4                 4.25        1980
# 3946   3800000                   5                 5.50        1978
#
#        living area
# 10503        12050
# 2424         10040
# 9171          9890
# 6244          9200
# 10915         8010
# 2794          9640
# 2907          6430
# 10566         7080
# 12442         5770
# ...

# %%
# Check missing values
df.isnull().sum()
# Simple approach: Drop rows with missing values
df.dropna()
# OR: Fill missing values (if needed)
# df['column_name'].fillna(df['column_name'].median(), inplace=True)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
#SELECT IMPORTANT FEATURES
X = df[['living area','number of bedrooms','number of bathrooms','lot area','condition of the house','grade of the house','Built Year']]
Y = df['Price']

# %%
#TRAIN-TEST SPLIT ( SO WE CAN CHECK ACCURACY)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#BUILDING MODEL
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#PREDICT AND EVALUATE
from sklearn.metrics import r2_score , mean_absolute_error, mean_squared_error
Y_pred = model.predict(X_test)
print("R2 Score:", r2_score(Y_test, Y_pred))
print("Mean absolute error:", mean_absolute_error(Y_test, Y_pred))
print("Mean squared error:", np.sqrt(mean_squared_error(Y_test, Y_pred)))
# Out:
# R2 Score: 0.6420858405216228
# Mean absolute error: 143751.58208721125
# Mean squared error: 224581.5835329986

# %%
#MAKING PREDICTION ON NEW HOUSE DATA
new_house =[[2000,3,2,3000,4,7,2010]] #2000 sqft, 3bhk , 2 bathrooms
predicted_price = model.predict(new_house)
print("Predicted Price:", predicted_price[0])
# Out:
# Predicted Price: 313453.2124498645
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
